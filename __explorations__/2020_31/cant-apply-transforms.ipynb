# %%
from fastai2.vision.all import *

# %%
batch_tfms = aug_transforms(max_zoom=1.1, max_warp=0., max_rotate=0., max_lighting=0.0,do_flip=False)
batch_tfms
# Out:
# [AffineCoordTfm: (TensorBBox,object) -> encodes
#  (TensorPoint,object) -> encodes
#  (TensorImage,object) -> encodes
#  (TensorMask,object) -> encodes ]

# %%
path = untar_data(URLs.PETS)/'images'

# %%
images_path = get_image_files(path)

# %%
images = list(map(PILImage.create, images_path[:64]))

# %%
s = [ImageBlock, ToTensor, *batch_tfms]
p = Pipeline(s)
p #p(images)
# Out:
# Pipeline: ImageBlock -> ToTensor -> AffineCoordTfm

# %%
tls = TfmdLists(images, s) # tls = TfmdLists(images, p)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-66-b5fb93fc03d2> in <module>
# ----> 1 tls = TfmdLists(images, s) # tls = TfmdLists(images, p)
#
# ~/Documentos/github/fastcore/fastcore/foundation.py in __call__(cls, x, *args, **kwargs)
#      45             return x
#      46
# ---> 47         res = super().__call__(*((x,) + args), **kwargs)
#      48         res._newchk = 0
#      49         return res
#
# ~/Documentos/github/fastai2/fastai2/data/core.py in __init__(self, items, tfms, use_list, do_setup, split_idx, train_setup, splits, types, verbose, dl_type)
#     221         if do_setup:
#     222             pv(f"Setting up {self.tfms}", verbose)
# --> 223             self.setup(train_setup=train_setup)
#     224
#     225     def _new(self, items, split_idx=None, **kwargs):
#
# ~/Documentos/github/fastai2/fastai2/data/core.py in setup(self, train_setup)
# ...

# %%
tls
# Out:
# TfmdLists: [PILImage mode=RGB size=500x333, PILImage mode=RGB size=500x333, PILImage mode=RGB size=500x332, PILImage mode=RGB size=500x375, PILImage mode=RGB size=375x500, PILImage mode=RGB size=500x335, PILImage mode=RGB size=400x318, PILImage mode=RGB size=375x500, PILImage mode=RGB size=225x300, PILImage mode=RGB size=225x300, PILImage mode=RGB size=500x334, PILImage mode=RGB size=500x416, PILImage mode=RGB size=500x358, PILImage mode=RGB size=500x400, PILImage mode=RGB size=500x333, PILImage mode=RGB size=300x202, PILImage mode=RGB size=500x456, PILImage mode=RGB size=360x270, PILImage mode=RGB size=500x388, PILImage mode=RGB size=500x333, PILImage mode=RGB size=335x500, PILImage mode=RGB size=217x300, PILImage mode=RGB size=300x225, PILImage mode=RGB size=500x500, PILImage mode=RGB size=500x335, PILImage mode=RGB size=500x332, PILImage mode=RGB size=360x480, PILImage mode=RGB size=200x300, PILImage mode=RGB size=500x375, PILImage mode=RGB size=500x333, PILImage mode=RGB size=375
# ...

# %%
tls[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-f2958087cbb1> in <module>
# ----> 1 tls[0]
#
# ~/Documentos/github/fastai2/fastai2/data/core.py in __getitem__(self, idx)
#     264         res = super().__getitem__(idx)
#     265         if self._after_item is None: return res
# --> 266         return self._after_item(res) if is_indexer(idx) else res.map(self._after_item)
#     267
#     268 # Cell
#
# ~/Documentos/github/fastai2/fastai2/data/core.py in _after_item(self, o)
#     227         return super()._new(items, tfms=self.tfms, do_setup=False, types=self.types, split_idx=split_idx, **kwargs)
#     228     def subset(self, i): return self._new(self._get(self.splits[i]), split_idx=i)
# --> 229     def _after_item(self, o): return self.tfms(o)
#     230     def __repr__(self): return f"{self.__class__.__name__}: {self.items}\ntfms - {self.tfms.fs}"
# ...
